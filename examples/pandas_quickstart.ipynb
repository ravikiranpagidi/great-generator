# %% [markdown]
# # Great Generator quickstart
# Generate a realistic ecommerce domain in one line.

# %%
from great_generator import generate_domain

data = generate_domain('ecommerce', scale='tiny', seed=42)
data['orders'].head()
